# %% [markdown]
# # Homework 01:
#
# ### Corresponding to lessons 0 & 1.
#
# 1. Use the command line to find some folders that you frequently use in your computer. Use the command line to change all file names such that they contain no spaces.
# 2. Use the command line to find some folders that are unneeded in your computer. Use the command line to delete all of the files.
# 3. Use the command find to find some folders that are unorganized and many different types of documents/files and could be arranged more neatly into subfolders. Use the command line to create folders for designated subtopics and move the relevant files to their corresponding folders.
# 4. Use a markdown cell to write the following mathematical equations (I just found some random ones in from my classwork) in LaTeX format.

# %%
from skimage import io
img = io.imread('1.png')
io.imshow(img)

# %%
img = io.imread('2.png')
io.imshow(img)
