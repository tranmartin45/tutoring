# %%
s1 = "ubsu"
s2 = "b"
if s1 < s2:
    l = list(s2)
    s = list(s1)
else:
    l = list(s1)
    s = list(s2)
l0 = 0
l1 = len(l)
s0 = 0
s1 = len(s)
a = True
lc = True
lc1 = False
lc2 = False
lc3 = False
lc4 = False
sc = 0
while a is True:
    if s[s0:s1] == l[l0:l1]:
        print(s[s0:s1])
        a = False
    elif lc is True:
        l0 = l0 + 1
        if l0 == len(l):
            l0 = 0
            lc1 = True
            lc = False
    elif lc1 is True:
        l1 = l1 - 1
        if l1 == 0:
            l1 = len(l)
            lc2 = True
            lc1 = False
    elif lc2 is True:
        l0 = l0 + 1
        l1 = l1 - 1
        if l1 == 0 and l0 == len(l):
            l1 = len(l)
            l0 = 0
            lc3 = True
            lc2 = False
    elif lc3 is True:
        l0 = l0 + 2
        l1 = l1 - 1
        if l1 == 0 and l0 == len(l):
            l1 = len(l)
            l0 = 0
            lc4 = True
            lc3 = False
    elif lc4 is True:
        l0 = l0 + 1
        l1 = l1 - 2
        if l1 == 0 and l0 == len(l):
            l1 = len(l)
            l0 = 0
            sc = sc + 1
            lc3 = False
    elif sc == 1:
        s0 = s0 + 1
        if s0 == len(s):
            s0 = 0
    else:
        print("No")
